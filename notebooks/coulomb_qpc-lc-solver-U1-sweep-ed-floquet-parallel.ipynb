# %%
import os
import sys

# %%
import pathlib
import math
import numpy as np
import matplotlib.pyplot as plt
import qpc.tools as tools
from qpc.tools import mv
from qpc import evolution
from concurrent.futures import ProcessPoolExecutor

# %%
ed_list = np.linspace(-1, 2, num=30)

# %%
e = 1     # on-site energy
h = 0.05  # hopping

ns = 200 # number of sites in a single lead

e_ = [e]*ns
h_ = [h]*ns
chain = np.column_stack((e_, h_))
chain[0,1] = h # coupling to QPC

# %%
# save chain parameters
np.savetxt('./chain.txt', chain, delimiter=' ')

# %%
dt = 0.01

# %%
# find the light cone
# !qpc-prepare.py --tmax=800 --rtol=1E-5 --dt=0.01 --ringmax=5 --fout=lc
# Out:
# Wellcome to lightcone constructor version 01.03.2023-14.44
# Semiinfinite chain file:  chain.txt
# Length of chain:  200
# Relative significance treshold for forward lightcone boundary:  1e-05
# Maximal size of ring:  5
# Maximal time:  800.0
# Time step:  0.01
# Coupling to impurity:  0.05
# The execution time : 88.34469532966614  sec

# %%
import numpy as np
import subprocess
from concurrent.futures import ProcessPoolExecutor

# 1. Функция для запуска одной задачи
def run_quantum_job(var):
    # Формируем команду (f-строка подставит значение var)
    command = [
        "qpc-solve.py",
        "--maxcores=1", 
        "--cfrom=5", 
        "--cto=5", 
        "--csize=1", 
        "--U=1", 
        f"--e_d={var}", # Подставляем e_d
        "--fin=lc", 
        f"--fout=result_{var:.4f}", # Уникальное имя для каждого файла вывода
        "--nquanta=7", 
        "--tmax=800",
        "--A=0.1",
        "--w=0.5"
    ]
    
    print(f"Starting job for e_d = {var:.4f}")
    subprocess.run(command)
    return f"Done: {var}"

# 2. Запуск параллельно (например, в 4 потока/процесса)
# max_workers — сколько ядер выделить на параллельный запуск
with ProcessPoolExecutor(max_workers=30) as executor:
    results = list(executor.map(run_quantum_job, ed_list))

print("All jobs finished.")
# Out:
# Starting job for e_d = -0.7931Starting job for e_d = -1.0000Starting job for e_d = -0.8966Starting job for e_d = -0.6897Starting job for e_d = -0.5862Starting job for e_d = -0.3793Starting job for e_d = -0.1724Starting job for e_d = 0.2414Starting job for e_d = -0.4828Starting job for e_d = -0.2759
# Starting job for e_d = 0.5517Starting job for e_d = 0.1379Starting job for e_d = -0.0690Starting job for e_d = 0.0345
#
# Starting job for e_d = 0.4483Starting job for e_d = 0.3448Starting job for e_d = 0.7586Starting job for e_d = 0.8621
# Starting job for e_d = 1.0690Starting job for e_d = 0.6552
# Starting job for e_d = 0.9655
# Starting job for e_d = 1.3793Starting job for e_d = 1.1724
# Starting job for e_d = 1.2759
#
#
#
# Starting job for e_d = 1.4828
#
#
#
#
# Starting job for e_d = 1.8966Starting job for e_d = 2.0000
# Starting job for e_d = 1.7931
#
#
#
#
#
#
#
#
#
#
# Starting job for e_d = 1.5862
# Starting job for e_d = 1.6897
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.1379
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.13793103448275867
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.3793
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.3793103448275862
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.2759
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.2758620689655173
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.7931
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.793103448275862
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.5862
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.5862068965517242
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-1.0000
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -1.0
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.8966
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.896551724137931
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_2.0000
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  2.0
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.1724
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.1724137931034483
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.7586
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.7586206896551724
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.6552
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.6551724137931034
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.1724
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.1724137931034484
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.9655
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.9655172413793103
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.6897
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.6896551724137931
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# ...done
# ...done
# ...done
# ...done
# ...done
# ...done
# submitting jobs to pool ...
# ...done
# running chunk  5 , of  1  trajectories
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.6897
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.6896551724137931
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# submitting jobs to pool ...
# submitting jobs to pool ...
# ...done
# ...done
# running chunk  5 , of  1  trajectories
# running chunk  5 , of  1  trajectories
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.0690
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.0689655172413794
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# submitting jobs to pool ...
# ...done
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# running chunk  5 , of  1  trajectories
# submitting jobs to pool ...
# submitting jobs to pool ...
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# running chunk  5 , of  1  trajectories
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.3793
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.3793103448275863
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# running chunk  5 , of  1  trajectories
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# ...done
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.0690
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.06896551724137934
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# ...done
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.3448
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.3448275862068966
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.0345
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.034482758620689724
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# ...done
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.5517
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.5517241379310345
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# submitting jobs to pool ...
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# running chunk  5 , of  1  trajectories
# ...done
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.2759
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.27586206896551724
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.5862
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.5862068965517242
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# ...done
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# ...done
# ...done
# ...done
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.8621
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.8620689655172413
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# ...done
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.4828
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.48275862068965514
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# ...done
# ...done
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.4483
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.4482758620689655
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# submitting jobs to pool ...
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_-0.7931
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  -0.7931034482758621
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# submitting jobs to pool ...
# ...done
# running chunk  5 , of  1  trajectories
# running chunk  5 , of  1  trajectories
# ...done
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.4828
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.4827586206896552
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# ...done
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_1.8966
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  1.896551724137931
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# submitting jobs to pool ...
# ...done
# running chunk  5 , of  1  trajectories
# ...done
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# ...done
# Wellcome to lightcone impurity solver version 10.03.2023-11.51
# Will read the lightcone info from the current directory
# Will compute  1  trajectories
# on max  1  CPU cores
# Will save results into  result_0.2414
# Will load lightcones from  /home/e.polyakov/qpc/qpc/notebooks/lc
# Will simulate up to time 800.0
# Max number of coupled quanta:  7
# on-site energy:  1
# hopping:  0.05
# Gate voltage e_d:  0.24137931034482762
# Coulomb interaction U:  1
# Max number of coupled modes:  5
# computing sparse matrices...
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# ...done
# ...done
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# ...done
# submitting jobs to pool ...
# running chunk  5 , of  1  trajectories
# chunk  5  execution time:  711.8688585758209  sec
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  717.2162411212921  sec
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  722.7373557090759  sec
# chunk  5  execution time:  723.2700810432434  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  725.1645505428314  sec
# chunk  5  execution time:  724.684690952301  sec
# chunk  5  execution time:  725.1679537296295  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  726.621630191803  sec
# chunk  5  execution time:  726.1879415512085  sec
# chunk  5  execution time:  726.847570180893  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  727.7503983974457  sec
# chunk  5  execution time:  728.3202457427979  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  728.391969203949  sec
# chunk  5  execution time:  728.9011723995209  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  729.5496649742126  sec
# chunk  5  execution time:  729.4260709285736  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  731.6581308841705  sec
# chunk  5  execution time:  730.830644607544  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  734.9427988529205  sec
# chunk  5  execution time:  735.483818769455  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  735.8593926429749  sec
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  739.680581331253  sec
# chunk  5  execution time:  740.3803851604462  sec
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  740.8114542961121  sec
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  741.249755859375  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  742.1697223186493  sec
# chunk  5  execution time:  742.212329864502  sec
# finished  1 job  out of  1
#
# Done!
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  744.7882857322693  sec
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  749.4732992649078  sec
# finished  1 job  out of  1
#
# Done!
# chunk  5  execution time:  749.9731388092041  sec
# finished  1 job  out of  1
#
# Done!
# All jobs finished.

# %%
import numpy as np
import os
import pathlib

J_lc = []

for var in ed_list:
    folder = f"result_{var:.4f}"
    path_x = pathlib.Path(os.getcwd()) / folder / "x_5.txt"
    
    try:
        # Загружаем данные (первая колонка - Re, вторая - Im)
        xc = np.loadtxt(path_x)
        
        # Создаем комплексный массив x нужной длины
        # (Обычно длина совпадает с количеством строк в xc - 1)
        x = xc[1:, 0] + 1j * xc[1:, 1]
        
        # Ваша формула расчета (индексы 79900 и 10000)
        # ВАЖНО: убедитесь, что в x достаточно элементов для этих индексов
        val_799 = x[799 * 100]
        val_100 = x[100 * 100]
        
        current_j = (val_799 - val_100) / (699 * 100 * dt)
        J_lc.append(current_j)
        
    except Exception as e:
        print(f"Ошибка в папке {folder}: {e}")
        J_lc.append(np.nan) # Заполняем пропуском, если файл битый или отсутствует

# Превращаем в итоговый массив
J_lc = np.array(J_lc)

# %%
plt.plot(ed_list, J_lc)
plt.legend()
plt.xlabel('current')
plt.ylabel('e_d')
# Out:
# /tmp/ipykernel_205306/3904405644.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'e_d')
